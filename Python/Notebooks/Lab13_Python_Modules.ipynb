# %% [markdown]
# # Lab 13 — Python Modules
#
# Each question includes:
# - Markdown (problem)
# - Empty code cell
# - Solution code cell

# %% [markdown]
# ## 1. WAP to pick a random character from a given string.

# %%
# Write your solution for Q1 here

# %%
import random
s = 'VishalBaraiya'
print(random.choice(s))

# %% [markdown]
# ## 2. WAP to pick a random element from a given list.

# %%
# Write your solution for Q2 here

# %%
import random
lst = [10, 20, 30, 40, 50]
print(random.choice(lst))

# %% [markdown]
# ## 3. WAP to demonstrate the use of the math module.

# %%
# Write your solution for Q3 here

# %%
import math
print('Square root:', math.sqrt(25))
print('Factorial:', math.factorial(5))
print('Pi value:', math.pi)

# %% [markdown]
# ## 4. WAP to demonstrate the use of datetime module.

# %%
# Write your solution for Q4 here

# %%
from datetime import datetime, date
print('Current DateTime:', datetime.now())
print('Today:', date.today())

# %% [markdown]
# ## 5. WAP to create Calculator module (add, sub, mul, div) and another file to use the module.

# %%
# Write your solution for Q5 here

# %%
# calculator.py
# def add(a,b): return a+b
# def sub(a,b): return a-b
# def mul(a,b): return a*b
# def div(a,b): return a/b

# main.py
# import calculator as c
# print(c.add(5,3))
print('Calculator module example shown in comments')
