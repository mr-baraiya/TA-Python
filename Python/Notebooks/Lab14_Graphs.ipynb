# %% [markdown]
# # Lab 14 — Graphs using Matplotlib
#
# Each question includes:
# - Markdown (problem)
# - Empty code cell
# - Solution code cell
#
# Note: These programs use Matplotlib. Run them in an environment that supports plotting.

# %% [markdown]
# ## 1. WAP to demonstrate the use of Pie chart.

# %%
# Write your solution for Q1 here

# %%
import matplotlib.pyplot as plt
sizes = [30, 20, 25, 25]
labels = ['A','B','C','D']
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title('Pie Chart Example')
plt.show()

# %% [markdown]
# ## 2. WAP to plot list of random X, Y coordinates in Matplotlib.

# %%
# Write your solution for Q2 here

# %%
import matplotlib.pyplot as plt
import random
x = [random.randint(1,50) for _ in range(20)]
y = [random.randint(1,50) for _ in range(20)]
plt.scatter(x, y)
plt.title('Random X-Y Plot')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# ## 3. WAP to demonstrate the use of Bar chart.

# %%
# Write your solution for Q3 here

# %%
import matplotlib.pyplot as plt
x = ['A','B','C','D']
y = [10,20,15,30]
plt.bar(x,y)
plt.title('Bar Chart Example')
plt.show()

# %% [markdown]
# ## 4. WAP to demonstrate the use of Histogram.

# %%
# Write your solution for Q4 here

# %%
import matplotlib.pyplot as plt
import random
data = [random.randint(1,100) for _ in range(50)]
plt.hist(data, bins=10)
plt.title('Histogram Example')
plt.show()

# %% [markdown]
# ## 5. WAP to display the value of each bar in a bar chart using Matplotlib.

# %%
# Write your solution for Q5 here

# %%
import matplotlib.pyplot as plt
x = ['A','B','C','D']
y = [10,20,15,30]
plt.bar(x,y)
for i,val in enumerate(y):
    plt.text(i, val, str(val), ha='center', va='bottom')
plt.title('Bar Chart with Values')
plt.show()

# %% [markdown]
# ## 6. WAP to create a Scatter Plot with several colours in Matplotlib.

# %%
# Write your solution for Q6 here

# %%
import matplotlib.pyplot as plt
import random
x = [random.randint(1,50) for _ in range(20)]
y = [random.randint(1,50) for _ in range(20)]
colors = [random.randint(1,100) for _ in range(20)]
plt.scatter(x, y, c=colors)
plt.title('Colored Scatter Plot')
plt.show()

# %% [markdown]
# ## 7. WAP to demonstrate the use of Box Plot.

# %%
# Write your solution for Q7 here

# %%
import matplotlib.pyplot as plt
import random
data = [random.randint(1,100) for _ in range(50)]
plt.boxplot(data)
plt.title('Box Plot Example')
plt.show()
