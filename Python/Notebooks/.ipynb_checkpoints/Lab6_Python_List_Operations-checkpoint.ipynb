# %% [markdown]
# # Lab 6 — Python List Operations

# %% [markdown]
# ## 1. WAP to find sum of all the elements in a list.

# %%
lst = [1,2,3,4,5]
ans = 0
for i in lst:
    ans += i
print(ans)
print(sum(lst))
# Out:
# 15
# 15

# %% [markdown]
# ## 2. WAP to find the largest element in a list.

# %%
lst = [12, 45, 67, 2]
max_no = 0
for i in lst:
    if max_no < i:
        max_no = i
print(max_no)
print(max(lst))
# Out:
# 67
# 67

# %% [markdown]
# ## 3. WAP to find the length of a list.

# %%
lst = [3,5,7,9]
count = 0
for _ in lst:
    count += 1
print('Length =', count)
print('Length =', len(lst))
# Out:
# Length = 4
# Length = 4

# %% [markdown]
# ## 4. WAP to interchange first and last elements in a list.

# %%
lst = [10,20,30,40]
lst[0], lst[-1] = lst[-1], lst[0]
print(lst)

# %% [markdown]
# ## 5. WAP to split the list into two parts and append the first part to the end.

# %%
lst = [1,2,3,4,5,6]
mid = len(lst)//2
new_list = lst[mid:] + lst[:mid]
print(new_list)
# Out:
# [4, 5, 6, 1, 2, 3]

# %% [markdown]
# ## 6. WAP to interchange the elements on two positions entered by a user.

# %%
arr = [10, 20, 30, 40, 50]

print("Original array:", arr)

pos1 = int(input("Enter first position : ")) - 1
pos2 = int(input("Enter second position : ")) - 1

if 0 <= pos1 < len(arr) and 0 <= pos2 < len(arr):
    arr[pos1], arr[pos2] = arr[pos2], arr[pos1]
    print("Array after swapping:", arr)
else:
    print("Invalid positions!")
# Out:
# Original array: [10, 20, 30, 40, 50]
# Enter first position to swap:  2
# Enter second position to swap:  4
# Array after swapping: [10, 40, 30, 20, 50]

# %% [markdown]
# ## 7. WAP to reverse a list given by user.

# %%
n = int(input("Enter size of list: "))

arr = []

for i in range(n):
    val = int(input(f"Enter element {i+1}: "))
    arr.append(val)

print("Original list:", arr)

reversed_list = arr[::-1]

print("Reversed list:", reversed_list)

# %% [markdown]
# ## 8. WAP to print even numbers in a list.

# %%
arr = list(map(int, input("Enter numbers separated by space: ").split()))

print("Even numbers in the list:")

for num in arr:
    if num % 2 == 0:
        print(num, end=" ")
# Out:
# Enter numbers separated by space:  12 45 23 69 74
# Even numbers in the list:
# 12 74

# %% [markdown]
# ### 9. WAP to count unique items in a list.

# %%
my_list = [1, 2, 2, 3, 4, 4, 5]
unique_count = len(set(my_list))

print("Number of unique items:", unique_count)
# Out:
# Number of unique items: 5

# %% [markdown]
# ## 10. WAP to copy a list.

# %%
arr = [10, 20, 30, 40]
copy_arr = arr.copy()

print("Original:", arr)
print("Copy:", copy_arr)
# Out:
# Original: [10, 20, 30, 40]
# Copy: [10, 20, 30, 40]

# %% [markdown]
# ## 11. WAP to print all odd numbers in a given range.

# %%
arr = list(map(int, input("Enter list elements: ").split()))

start = int(input("Enter start index: "))
end = int(input("Enter end index: "))

print("Odd numbers in the given index range:")

for i in range(start, end + 1):
    if arr[i] % 2 != 0:
        print(arr[i], end=" ")
# Out:
# Enter list elements:  12 45 36 96 74 23 21 15 28 29
# Enter start index:  2
# Enter end index:  8
# Odd numbers in the given index range:
# 23 21 15

# %% [markdown]
# ## 12. WAP to count occurrences of an element in a list.

# %%
arr = list(map(int, input("Enter elements separated by space: ").split()))

x = int(input("Enter element to count: "))

count = 0
for num in arr:
    if num == x:
        count += 1

print(f"{x} occurs {count} time(s) in the list.")
# Out:
# Enter elements separated by space:  12 23 56 78 96 14 4 52 4
# Enter element to count:  4
# 4 occurs 2 time(s) in the list.

# %% [markdown]
# ## 13. WAP to find second largest number in a list.

# %%
arr = list(map(int, input("Enter elements: ").split()))

if len(arr) < 2:
    print("Second largest does not exist.")
else:
    largest = float('-inf')
    second_largest = float('-inf')

    for num in arr:
        if num > largest:
            second_largest = largest
            largest = num
        elif num > second_largest and num != largest:
            second_largest = num

    if second_largest == float('-inf'):
        print("Second largest does not exist.")
    else:
        print("Second largest number is:", second_largest)

# %% [markdown]
# ## 14. WAP to extract elements with frequency greater than K.

# %%
arr = list(map(int, input("Enter list elements: ").split()))
k = int(input("Enter value of K: "))

freq = {}

for num in arr:
    if num in freq:
        freq[num] += 1
    else:
        freq[num] = 1

print(f"Elements with frequency greater than {k}:")

for key in freq:
    if freq[key] > k:
        print(key, end=" ")

# lst = [1,2,2,3,3,3,4,4]
# K = 2
# from collections import Counter
# freq = Counter(lst)
# result = [item for item, count in freq.items() if count > K]
# print(result)
# Out:
# Enter list elements:  1 1 1 2 2 2 2 4 5 6 3 3 3 1 1 1
# Enter value of K:  2
# Elements with frequency greater than 2:
# 1 2 3
