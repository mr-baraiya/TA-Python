# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="10"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 2</b></center>
# <pre>

# %% [markdown]
# # Lab 2 — Perform basic mathematical formula-based programs.
#
# **Course:** 2301CS404 — Python Programming (Lab)

# %% [markdown]
# ## 1. WAP to print "Hello World.!"
#
# Print `Hello World.!` to the console.

# %%
print('Hello World.!')
# Out:
# Hello World.!

# %% [markdown]
# ## 2. WAP to print addition of two numbers with and without using input().
#
# Show addition of two numbers. First use fixed values, then demonstrate using input().

# %%
a = float(input('Enter first number: '))
b = float(input('Enter second number: '))
print('Sum (input):', a + b)
# Out:
# Enter first number:  45
# Enter second number:  56
# Sum (input): 101.0

# %% [markdown]
# ## 3. WAP to check the type of the variable.
#
# Demonstrate `type()` on different variables.

# %%
a = 10
b = 3.14
c = 'hello'
print(type(a), type(b), type(c))
# Out:
# <class 'int'> <class 'float'> <class 'str'>

# %% [markdown]
# ## 4. WAP to calculate simple interest.
#
# Simple interest = (P * R * T) / 100

# %%
P = float(input("Enter Principal (P): "))
R = float(input("Enter Rate (R): "))
T = float(input("Enter Time (T): "))

si = (P * R * T) / 100

print(f"Simple Interest = {si}")
# Out:
# Enter Principal (P):  4500
# Enter Rate (R):  10
# Enter Time (T):  12
# Simple Interest = 5400.0

# %% [markdown]
# ## 5. WAP to calculate area and perimeter of a circle.
#
# Given radius r: area = πr², perimeter = 2πr

# %%
import math
r = float(input("Enter radius: "))
area = math.pi * r**2
perimeter = 2 * math.pi * r
print(f'Radius={r} -> Area={area:.4f}, Perimeter={perimeter:.4f}')
# Out:
# Enter radius:  7.2
# Radius=7.2 -> Area=162.8602, Perimeter=45.2389

# %% [markdown]
# ## 6. WAP to calculate area of a triangle.
#
# Given base and height: area = 0.5 * base * height

# %%
base = float(input("Enter base: "))
height = float(input("Enter height: "))
area = 0.5 * base * height
print(f'Area = {area}')
# Out:
# Enter base:  45
# Enter height:  50
# Area = 1125.0

# %% [markdown]
# ## 7. WAP to compute quotient and remainder.
#
# Given two integers a and b compute quotient and remainder.

# %%
a = int(input("Enter a: "))
b = int(input("Enter b: "))
quotient = a // b
remainder = a % b
print('Quotient =', quotient)
print('Remainder =', remainder)
# Out:
# Enter a:  56
# Enter b:  4
# Quotient = 14
# Remainder = 0

# %% [markdown]
# ## 8. WAP to convert degree into Fahrenheit and vice versa.
#
# Celsius ↔ Fahrenheit conversions

# %%
C = float(input("Enter Celsius: "))
F = (C * 9/5) + 32
print(f'{C}°C = {F}°F')

F2 = float(input("Enter Fahrenheit: "))
C2 = (F2 - 32) * 5/9
print(f'{F2}°F = {C2:.2f}°C')
# Out:
# Enter Celsius:  45
# 45.0°C = 113.0°F
# Enter Fahrenheit:  56
# 56.0°F = 13.33°C

# %% [markdown]
# ## 9. WAP to find the distance between two points in 2-D space.
#
# Distance between (x1,y1) and (x2,y2) = sqrt((x2-x1)^2 + (y2-y1)^2)

# %%
import math

x1 = float(input("Enter x1: "))
y1 = float(input("Enter y1: "))
x2 = float(input("Enter x2: "))
y2 = float(input("Enter y2: "))

d = (((x2 - x1)**2) + ((y2 - y1)**2))**0.5
print(f'Distance = {d}')

d = math.hypot(x2 - x1, y2 - y1)
print(f'Distance = {d}')
# Out:
# Enter x1:  4
# Enter y1:  5
# Enter x2:  6
# Enter y2:  7
# Distance = 2.8284271247461903
# Distance = 2.8284271247461903

# %% [markdown]
# ## 10. WAP to print sum of n natural numbers.
#
# Sum = n*(n+1)/2

# %%
n = int(input("Enter the number : "))
s = n * (n + 1) // 2
print(f'Sum of first {n} natural numbers =', s)
# Out:
# Enter the number :  5
# Sum of first 5 natural numbers = 15

# %% [markdown]
# ## 11. WAP to print sum of square of n natural numbers.
#
# Sum of squares = n*(n+1)*(2n+1)/6

# %%
n = int(input("Enter the number : "))
squares_sum = n * (n + 1) * (2*n + 1) // 6
print('Sum of squares =', squares_sum)
# Out:
# Enter the number :  5
# Sum of squares = 55

# %% [markdown]
# ## 12. WAP to concate the first and last name of the student.
#
# Join first name and last name with a space.

# %%
first = 'Vishal'
last = 'Baraiya'
full = first + ' ' + last
print('Full Name =', full)
# Out:
# Full Name = Vishal Baraiya

# %% [markdown]
# ## 13. WAP to swap two numbers.
#
# Swap two variables (show with and without temp variable).

# %%
a, b = 7, 9
print('Before:', a, b)
# Using tuple unpacking
a, b = b, a
print('After (tuple unpack):', a, b)
# Using temp variable example
x, y = 1, 2
temp = x
x = y
y = temp
print('Swapped with temp:', x, y)
# Out:
# Before: 7 9
# After (tuple unpack): 9 7
# Swapped with temp: 2 1

# %% [markdown]
# ## 14. WAP to convert kilometers to meter, feet, inches and centimeter.
#
# Convert km to m, ft, in, cm.

# %%
km = 3.5
meters = km * 1000
feet = km * 3280.839895
inches = km * 39370.07874
cm = km * 100000
print(f'{km} km = {meters} m = {feet:.2f} ft = {inches:.2f} in = {cm} cm')
# Out:
# 3.5 km = 3500.0 m = 11482.94 ft = 137795.28 in = 350000.0 cm

# %% [markdown]
# ## 15. WAP to get day, month and year from the user and print the date in format DD-MM-YYYY.
#
# Format and print a date like 20-10-2024

# %%
d = int(input('Day: '))
m = int(input('Month: '))
y = int(input('Year: '))
print(f'Date: {d:02d}-{m:02d}-{y}')
# Out:
# Day:  2
# Month:  2
# Year:  2301
# Date: 02-02-2301
