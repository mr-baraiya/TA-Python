# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 11</b></center>
# <pre>

# %% [markdown]
# # Exception Handling

# %% [markdown]
# ### 01) WAP to handle following exceptions:
# 1. ZeroDivisionError
# 2. ValueError
# 3. TypeError
# #### Note: handle them using separate except blocks and also using single except block too.

# %%
try:
    a = int(input("Enter the Number : "))
    b = int(input("Enter the Number : ")) # Value Error a = "str"
    c = a / b
    print (f"{a}/{b} = {c}") # Zero Division Error
    print('a'+1) # Type Error
except ZeroDivisionError :
    print("Zero Division Error")
except ValueError :
    print("Value Error")
except TypeError :
    print("Type Error")
# Out:
# Enter the Number :  5
# Enter the Number :  0
# Zero Division Error

# %% [markdown]
# ### 02)  WAP to handle following exceptions:
# 1. IndexError
# 2. KeyError

# %%
try:
    # a = [1, 2, 3]
    # print(a[5])  # IndexError

    d = {'a':1,'b':2,'c':3}
    print(d[2])  # KeyError
    
except IndexError as ie:
    print(type(ie).__name__,":",ie)
    print("Index Error is Occured.")
except KeyError as ke:
    print(type(ke).__name__,":",ke)
    print("Key Error is Occured.")
# Out:
# KeyError : 2
# Key Error is Occured.

# %% [markdown]
# ### 03) WAP to handle following exceptions:
# 1. FileNotFoundError
# 2. ModuleNotFoundError

# %%
try:
    import index
    
    # with open('demo.txt') as fp:
    #     print(fp.read())
except FileNotFoundError as e:
    print(type(e).__name__,e)
except ModuleNotFoundError as e:
    print(type(e).__name__,e)
# Out:
# ModuleNotFoundError No module named 'index'

# %% [markdown]
# ### 04) WAP that catches all type of exceptions in a single except block.

# %%
try :
    print(1/0)
except Exception as e:
    print(type(e).__name__,e)
# Out:
# ZeroDivisionError division by zero

# %% [markdown]
# ### 05) WAP to demonstrate else  and finally block.

# %%
try:
    a = int(input("Enter the Number : "))
    b = int(input("Enter the Number : "))
    ans = a / b
    print(f"{a} / {b} = {ans}")
except Exception as e:
    print(type(e).__name__,e)
else:
    print("Else block Executed!") # It will Execute when Error Will not Occured
finally:
    print("Finally block Executed!") # It will Execute Every Time
# Out:
# Enter the Number :  5
# Enter the Number :  0
# ZeroDivisionError division by zero
# Finally block Executed!

# %% [markdown]
# ### 06) Create a short program that prompts the user for a list of grades separated by commas.
# ### Split the string into individual grades and use a list comprehension to convert each string to an integer.
# ### You should use a try statement to inform the user when the values they entered cannot be converted.

# %%
grades = input("Enter your Grades Seprated by commas : ")
grades_list  = grades.split(",")
int_list = []
try:
    int_list = [int(i) for i in grades_list]
except ValueError as ve:
    print(ve.args)
else:
    print(int_list)
# Out:
# Enter your Grades Seprated by commas :  12,hjk,45,78
# ("invalid literal for int() with base 10: 'hjk'",)

# %% [markdown]
# ### 07) WAP to create an udf divide(a,b) that handles ZeroDivisionError.

# %%
def divide(a,b):
    try:
        return a / b
    except ZeroDivisionError as zde:
        print(zde.args)

divide(23,0)
# Out:
# ('division by zero',)

# %% [markdown]
# ### 08) WAP that gets an age of a person form the user and raises ValueError with error message: "Enter Valid Age" :
# #### If the age is less than 18.
# #### otherwise print the age.

# %%
try:
    age = int(input("Enter the Age : "))
    if (age < 18):
        raise ValueError("This is Value Error Genrated By me.")
    else:
        print(f"Age = {age}")
        
except ValueError as e:
    print(type(e).__name__,e)
# Out:
# Enter the Age :  12
# ValueError This is Value Error Genrated By me.

# %% [markdown]
# ### 09) WAP to raise your custom Exception named InvalidUsernameError with the error message : "Username must be between 5 and 15 characters long":
# #### if the given name is having characters less than 5 or greater than 15.
# #### otherwise print the given username.

# %%
class InvalidUsernameError(Exception) :
    def __init__(self,msg):
        self.msg = msg
try:
    name = input("Enter the User Name : ")
    if(len(name) >= 5) and (len(name) <= 15):
        print(f"UserName : {name}")
    else:
        raise InvalidUsernameError("Username must be between 5 to 15 characters long")
except Exception as e:
    print(type(e).__name__,e)
# Out:
# Enter the User Name :  vi
# InvalidUsernameError Username must be between 5 to 15 characters long

# %% [markdown]
# ### 10) WAP to raise your custom Exception named NegativeNumberError with the error message : "Cannot calculate the square root of a negative number" :
# #### if the given number is negative.
# #### otherwise print the square root of the given number.

# %%
class NagativeNumberError(Exception) :
    def __init__(self,msg):
        self.msg = msg
try:
    n = int(input("Enter the number : "))
    if(n<0):
        raise NagativeNumberError("Number must be Greater then Zero.")
    else:
        print(f"n={n}")
except NagativeNumberError as e:
    print(type(e).__name__,e)
# Out:
# Enter the number :  -9
# NagativeNumberError Number must be Greater then Zero.
