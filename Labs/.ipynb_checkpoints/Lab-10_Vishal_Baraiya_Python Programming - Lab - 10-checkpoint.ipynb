# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 10</b></center>
# <pre>

# %% [markdown]
# # File I/O

# %% [markdown]
# ### 01) WAP to read and display the contents of a text file. (also try to open the file in some other directory)
# #### - in the form of a string
# #### - line by line
# #### - in the form of a list

# %%
# Read by File Pointer in another directory
# fp = open("D:\\Media\\demo.txt","r")
# for i in fp:
#     print(i,end="")
# fp.close()

# Read by File Pointer
fp = open("Demo.txt","r")
for i in fp:
    print(i,end="")
fp.close()

# Read by Read()
print("\n")
fp = open("Demo.txt","r")
print(fp.read())
fp.close()

# Read by Readline()
print("\n")
fp = open("Demo.txt","r")
while True:
    line = fp.readline()
    if not line:
        break
    print(line,end="")   
fp.close()

# Read by Readlines()
print("\n")
fp = open("Demo.txt","r")
l = fp.readlines()
print(l)
fp.close()
# Out:
# Hello! I am Vishal Baraiya.
#
# Hello! I am Vishal Baraiya.
#
#
# Hello! I am Vishal Baraiya.
#
# ['Hello! I am Vishal Baraiya.']

# %% [markdown]
# ### 02) WAP to create file named "new.txt" only if it doesn't exist.

# %%
fp = open("new.txt","w")
fp.write("Hello! world")
fp.close()

fp = open("new.txt","r")
print(fp.read())
fp.close()
# Out:
# Hello! world

# %% [markdown]
# ### 03) WAP to read first 5 lines from the text file.

# %%
with open('Demo.txt', 'r') as fp:
    for i in range(5):
        line = fp.readline()
        if not line:
            break
        print(line.strip())
# Out:
# Lorem Ipsum is simply dummy text of the printing and typesetting industry.
# Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book.

# %% [markdown]
# ### 04) WAP to find the longest word(s) in a file

# %%
with open('Demo.txt','r') as fp:
    wordlist = fp.read().split()
    longestword = ""
    for word in wordlist:
        if (len(word) > len(longestword)):
            longestword = word
    print(longestword)

# with open('Demo.txt', 'r') as fp:
#     wordlist = fp.read().split()
#     longestword = max(wordlist, key=len)
#     print(longestword)
# Out:
# typesetting,

# %% [markdown]
# ### 05) WAP to count the no. of lines, words and characters in a given text file.

# %%
with open("demo.txt","r") as fp:
    print("No. Of Lines : ",len(fp.readlines()))
    fp.seek(0,0)
    print("No. Of Words : ",len(fp.read().split()))
    fp.seek(0,0)
    print("No. Of Charcters : ",len(fp.read().replace("\n","")))
# Out:
# No. Of Lines :  8
# No. Of Words :  182
# No. Of Charcters :  1143

# %% [markdown]
# ### 06) WAP to copy the content of a file to the another file.

# %%
s = " "
with open("demo.txt","r") as fp:
    s = fp.read()
with open("demo-copy.txt","w") as fp:
    fp.write(s)
print("File Copied successfully!")
# Out:
# File Copied successfully!

# %% [markdown]
# ### 07) WAP to find the size of the text file.

# %%
import os

file_path = "demo.txt"

if os.path.exists(file_path):
    file_size = os.path.getsize(file_path)
    print(f"The size of the file '{file_path}' is {file_size} bytes.")
else:
    print(f"The file '{file_path}' does not exist.")
# Out:
# The size of the file 'demo.txt' is 1150 bytes.

# %% [markdown]
# ### 08) WAP to create an UDF named frequency to count occurances of the specific word in a given text file.

# %%
def frequency(file_path,word):
    with open(file_path,'r')as fp:
        l = fp.read().split()
        count = 0
        for i in l:
            if word.lower() == i.lower():
                count += 1
    print(f"Count Of {word} is = {count}")

frequency("demo.txt","Lorem")
# Out:
# Count Of Lorem is = 8

# %% [markdown]
# ### 09) WAP to get the score of five subjects from the user, store them in a file. Fetch those marks and find the highest score.

# %%
n = int(input("Enter The number of subjects:"))
with open("scores.txt","w") as fp:
    for i in range(n):
        temp = int(input(f"Enter the marks of Subi{i+1} : "))
        s = str(temp) + "\n"
        fp.write(s)
highest_marks = 0
with open("scores.txt","r") as fp:
    list_marks = [int(line) for line in fp.readlines()]
    highest_marks = max(list_marks)

print(f"Highest Marks : {highest_marks}")
# Out:
# Enter The number of subjects: 5
# Enter the marks of Subi1 :  45
# Enter the marks of Subi2 :  78
# Enter the marks of Subi3 :  96
# Enter the marks of Subi4 :  12
# Enter the marks of Subi5 :  74
# Highest Marks : 96

# %% [markdown]
# ### 10) WAP to write first 100 prime numbers to a file named primenumbers.txt
# (Note: each number should be in new line)

# %%
def isPrime(n = int):
    for i in range(2,n//2+2):
        if(n % i == 0):
            return False
    else:
        return True
with open("primenumbers.txt","w") as fp:
    i,count = 2,0
    while(count != 100):
        if isPrime(i):
            fp.write(str(i))
            fp.write("\n")
            count += 1
        i += 1
print("File Write Successfully!")
# Out:
# File Write Successfully!

# %% [markdown]
# ### 11) WAP to merge two files and write it in a new file.

# %%
fp1 = open("scores.txt","r")
fp2 = open("primenumbers.txt")
fp3 = open("merged.txt","w")
fp3.write(fp1.read())
fp3.write(fp2.read())
fp1.close()
fp2.close()
fp3.close()
print("File Merged Successfully!")
# Out:
# File Merged Successfully!

# %% [markdown]
# ### 12) WAP to replace word1 by word2 of a text file. Write the updated data to new file.

# %%
word1 = input("Enter th word1 : ")
word2 = input("Enter th word2 : ")
s = " "
fp1 = open("demo.txt","r")
fp2 = open("new.txt","w")
s = fp1.read()
fp2.write(s.replace(word1,word2))
fp1.close()
fp2.close()
print("Successfully complated!")
# Out:
# Enter th word1 :  Lorem
# Enter th word2 :  aaaaa
# Successfully complated!

# %% [markdown]
# ### 13) Demonstrate tell() and seek() for all the cases(seek from beginning-end-current position) taking a suitable example of your choice.

# %%
with open("demo.txt","rb") as fp:
    print(fp.read(10))
    print("Current Position : ",fp.tell())
    fp.seek(3,0) # 0 is use for from begining to 3 offset
    print("Current Position : ",fp.tell())
    fp.seek(5,1) # 1 is use for from Current Position to 5 offset
    print("Current Position : ",fp.tell())
    fp.seek(-3,2) # 2 is use for from ending to -3 offset
    print("Current Position : ",fp.tell())

# seek() second args 1,2 use in only binary files
# Out:
# b'Lorem Ipsu'
# Current Position :  10
# Current Position :  3
# Current Position :  8
# Current Position :  1147
